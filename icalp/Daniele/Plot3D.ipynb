# %%
import plotly.express as px
import numpy as np
import plotly.graph_objects as go

# %%
matrix=np.load(r"C:\Users\Daniele\Desktop\Graph mining\graphs\icalpw\icalpwEnriched2001_mvsMatrix.npy")
fig=go.Figure(data=[go.Scatter3d(x=matrix[0],y=matrix[1],z=matrix[2],mode='markers',marker=dict(
            color='red',
            size=[5],
            sizemode='diameter'
        )
    )])
fig.show()
# Out:
# <div>                            <div id="f8391ad3-2521-48cd-bf15-5b53d35aedf2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8391ad3-2521-48cd-bf15-5b53d35aedf2")) {                    Plotly.newPlot(                        "f8391ad3-2521-48cd-bf15-5b53d35aedf2",                        [{"marker":{"color":"red","size":[5],"sizemode":"diameter"},"mode":"markers","x":[11.884319140159123,11.885904255014191,0.2679130548427778,6.750719669203763,6.879445458162375,-3.0843563088224064,-3.534105534758598,-2.6578250164236685,-1.0666006327521704,-1.9145989435784425,-1.342767972445183,-1.6284937782810418,-0.24856235056584824,-0.22639137548042396,-1.2936995331725316,-3.534105534758598,-3.0832451013704385,3.5714530259618216,-2.8730102262404635,-2.515440754851
# ...
